# %%
import pandas as pd

# %%
weather=pd.read_csv("local_weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2022-01-24  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-25  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-26  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-27  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
# ...

# %%
# Fixing any missing values present
weather.apply(pd.isnull).sum()/weather.shape[0] #gives % of null values in each col.
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.653360
# ACSH       0.653360
# AWND       0.522451
# DAPR       0.999525
# FMTM       0.870099
# FRGT       0.999881
# MDPR       0.999525
# PGTM       0.495106
# PRCP       0.016668
# SNOW       0.324990
# SNWD       0.317634
# TAVG       0.879174
# TMAX       0.000534
# TMIN       0.000593
# TSUN       0.931728
# WDF1       0.653360
# WDF2       0.522392
# WDF5       0.527552
# WDFG       0.746901
# WSF1       0.653360
# WSF2       0.522332
# WSF5       0.527552
# WSFG       0.746901
# WT01       0.779939
# WT02       0.980248
# WT03       0.992941
# WT04       0.999763
# WT05       0.998339
# WT07       0.999881
# WT08       0.810368
# WT09       0.999881
# WT16       0.884038
# WT18       0.999822
# dtype: float64

# %%
#select the most important cols
core_weather=weather[["PRCP","SNOW","SNWD","TMAX","TMIN"]].copy()

# %%
#renaming the cols in my copy of the dataframe
core_weather.columns=["precip","snow","snow_depth","temp_max","temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01     0.0   0.0         0.0      49.0      30.0
# 1960-01-02     0.0   0.0         0.0      49.0      29.0
# 1960-01-03     0.0   0.0         0.0      54.0      35.0
# 1960-01-04     0.0   0.0         0.0      54.0      36.0
# 1960-01-05     0.0   0.0         0.0      55.0      33.0
# ...            ...   ...         ...       ...       ...
# 2022-01-24     0.0   NaN         NaN      60.0      39.0
# 2022-01-25     0.0   NaN         NaN      57.0      43.0
# 2022-01-26     0.0   NaN         NaN      57.0      41.0
# 2022-01-27     0.0   NaN         NaN      67.0      39.0
# 2022-01-28     0.0   NaN         NaN      64.0      39.0
#
# [16859 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]  #finding null val
# Out:
# precip        0.016668
# snow          0.324990
# snow_depth    0.317634
# temp_max      0.000534
# temp_min      0.000593
# dtype: float64

# %%
core_weather["snow"].value_counts()  #to see if we need to consider as imp.
# Out:
# snow
# 0.0    11379
# 1.0        1
# Name: count, dtype: int64

# %%
#delete the col.
del core_weather["snow"]

# %%
core_weather["snow_depth"].value_counts()
# Out:
# snow_depth
# 0.0    11504
# Name: count, dtype: int64

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-29     NaN      67.0      57.0
# 1983-10-30     NaN      70.0      63.0
# 1983-10-31     NaN      69.0      61.0
# 1983-11-12     NaN      63.0      55.0
# 1983-11-13     NaN      60.0      50.0
# ...            ...       ...       ...
# 2013-12-15     NaN      58.0      33.0
# 2016-05-01     NaN      80.0      55.0
# 2016-05-02     NaN      68.0      53.0
# 2016-05-08     NaN      67.0      56.0
# 2017-10-28     NaN      68.0      50.0
#
# [281 rows x 3 columns]

# %%
core_weather.loc["2013-12-15",:]
# Out:
# precip       NaN
# temp_max    58.0
# temp_min    33.0
# Name: 2013-12-15, dtype: float64

# %%
core_weather["precip"].value_counts()/core_weather.shape[0]
# Out:
# precip
# 0.00    0.810487
# 0.01    0.025980
# 0.02    0.011804
# 0.03    0.007236
# 0.04    0.006050
#           ...
# 1.29    0.000059
# 1.73    0.000059
# 1.05    0.000059
# 1.38    0.000059
# 1.02    0.000059
# Name: count, Length: 176, dtype: float64

# %%
core_weather["precip"]=core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip       0
# temp_max     9
# temp_min    10
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20     0.0       NaN       NaN
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2013-06-16     0.0       NaN       NaN
# 2020-08-29     0.0       NaN       NaN
# 2020-09-08     0.0       NaN       NaN
# 2020-09-09     0.0       NaN       NaN

# %%
core_weather.loc["2011-12-18":"2011-12-28"]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2011-12-18     0.0      52.0      33.0
# 2011-12-19     0.0      55.0      35.0
# 2011-12-20     0.0      61.0      35.0
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2011-12-26     0.0      50.0      32.0
# 2011-12-27     0.0      56.0      39.0
# 2011-12-28     0.0      57.0      38.0

# %%
core_weather=core_weather.fillna(method="ffill")
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_23608\4229891305.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   core_weather=core_weather.fillna(method="ffill")

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]  #seeing if we have any null values left
#we see no missing values
# Out:
# precip      0.0
# temp_max    0.0
# temp_min    0.0
# dtype: float64

# %%
# Check for missing value defined in data documentation
core_weather.apply(lambda x:(x==9999).sum())  # since 9s in a field indicate missing data as per documentation
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04', '1960-01-05',
#        '1960-01-06', '1960-01-07', '1960-01-08', '1960-01-09', '1960-01-10',
#        ...
#        '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-22', '2022-01-23',
#        '2022-01-24', '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28'],
#       dtype='object', name='DATE', length=16859)

# %%
core_weather.index=pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-22',
#                '2022-01-23', '2022-01-24', '2022-01-25', '2022-01-26',
#                '2022-01-27', '2022-01-28'],
#               dtype='datetime64[ns]', name='DATE', length=16859, freq=None)

# %%
core_weather.index.year
# Out:
# Index([1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960,
#        ...
#        2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022],
#       dtype='int32', name='DATE', length=16859)

# %%
core_weather[["temp_max","temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()  #we see that we are missing data from some years
# Out:
# DATE
# 1960    366
# 1961    365
# 1962    365
# 1963    365
# 1964    366
# 1965    365
# 1966    365
# 1967    365
# 1968    366
# 1969    365
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1983    184
# 1984    366
# 1985    365
# 1986    212
# 2000    365
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    365
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    364
# 2022     28
# Name: count, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"] #tells how  much rain in each year
# Out:
# DATE
# 1960    14.01
# 1961    13.87
# 1962    22.47
# 1963    19.11
# 1964    16.83
# 1965    16.32
# 1966    13.11
# 1967    23.98
# 1968    17.19
# 1969    25.70
# 1970    25.31
# 1971    10.61
# 1972    16.27
# 1973    29.37
# 1974    16.87
# 1975    17.54
# 1976     8.64
# 1977    11.70
# 1978    22.57
# 1979    23.79
# 1980    13.58
# 1983     7.13
# 1984    16.03
# 1985     8.50
# 1986     0.00
# 2000    21.09
# 2001    22.84
# 2002    19.12
# 2003    11.37
# 2004    12.97
# 2005    27.37
# 2006    22.79
# 2007    12.79
# 2008    13.86
# 2009    14.57
# 2010    22.67
# 2011    16.06
# 2012    22.93
# 2013     4.89
# 2014    19.62
# 2015     8.58
# 2016    19.77
# 2017    23.34
# 2018    16.82
# 2019    20.00
# 2020     6.42
# 2021    20.82
# 2022     0.25
# Name: precip, dtype: float64

# %%
core_weather.groupby(core_weather.index.year).apply(lambda x:x["precip"].sum()).plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# # Training model

# %%
core_weather["target"]=core_weather.shift(-1)["temp_max"]  #predicting tomm's temp. using today's data

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1960-01-31    0.00      59.0      46.0    62.0        NaN       0.941808
# 1960-02-01    0.81      62.0      51.0    59.0        NaN       0.903226
# 1960-02-02    0.00      59.0      43.0    59.0        NaN       0.951977
# 1960-02-03    0.20      59.0      47.0    60.0        NaN       0.954802
# 1960-02-04    0.16      60.0      42.0    60.0        NaN       0.941667
# ...            ...       ...       ...     ...        ...            ...
# 2022-01-23    0.00      60.0      41.0    60.0  56.900000       0.948333
# 2022-01-24    0.00      60.0      39.0    57.0  57.066667       0.951111
# 2022-01-25    0.00      57.0      43.0    57.0  57.200000       1.003509
# 2022-01-26    0.00      57.0      41.0    67.0  57.400000       1.007018
# 2022-01-27    0.00      67.0      39.0     NaN  57.933333       0.864677
#
#              max_min
# DATE
# 1960-01-31  1.282609
# 1960-02-01  1.215686
# ...

# %%
core_weather=core_weather.iloc[:-1,:].copy() #remove the last row to avoid the missing value

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1960-01-31    0.00      59.0      46.0    62.0        NaN       0.941808
# 1960-02-01    0.81      62.0      51.0    59.0        NaN       0.903226
# 1960-02-02    0.00      59.0      43.0    59.0        NaN       0.951977
# 1960-02-03    0.20      59.0      47.0    60.0        NaN       0.954802
# 1960-02-04    0.16      60.0      42.0    60.0        NaN       0.941667
# ...            ...       ...       ...     ...        ...            ...
# 2022-01-22    0.00      69.0      44.0    60.0  56.833333       0.823671
# 2022-01-23    0.00      60.0      41.0    60.0  56.900000       0.948333
# 2022-01-24    0.00      60.0      39.0    57.0  57.066667       0.951111
# 2022-01-25    0.00      57.0      43.0    57.0  57.200000       1.003509
# 2022-01-26    0.00      57.0      41.0    67.0  57.400000       1.007018
#
#              max_min
# DATE
# 1960-01-31  1.282609
# 1960-02-01  1.215686
# ...

# %%
from sklearn.linear_model import Ridge
reg=Ridge(alpha=.1)

# %%
predictors=["precip","temp_max","temp_min"]

# %%
train=core_weather.loc[:"2020-12-31"] #manually setting our training and test set

# %%
test=core_weather.loc["2021-01-01":]

# %%
reg.fit(train[predictors],train["target"]) #model has been fit
# Out:
# Ridge(alpha=0.1)

# %%
train
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1960-01-31    0.00      59.0      46.0    62.0        NaN       0.941808
# 1960-02-01    0.81      62.0      51.0    59.0        NaN       0.903226
# 1960-02-02    0.00      59.0      43.0    59.0        NaN       0.951977
# 1960-02-03    0.20      59.0      47.0    60.0        NaN       0.954802
# 1960-02-04    0.16      60.0      42.0    60.0        NaN       0.941667
# ...            ...       ...       ...     ...        ...            ...
# 2020-12-27    0.00      63.0      44.0    61.0  63.600000       1.009524
# 2020-12-28    0.10      61.0      42.0    60.0  63.500000       1.040984
# 2020-12-29    0.00      60.0      39.0    56.0  63.366667       1.056111
# 2020-12-30    0.07      56.0      36.0    62.0  63.100000       1.126786
# 2020-12-31    0.06      62.0      44.0    60.0  63.033333       1.016667
#
#              max_min
# DATE
# 1960-01-31  1.282609
# 1960-02-01  1.215686
# ...

# %%
test
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 2021-01-01    0.00      60.0      40.0    57.0  62.833333       1.047222
# 2021-01-02    0.14      57.0      51.0    56.0  62.533333       1.097076
# 2021-01-03    0.00      56.0      49.0    62.0  62.200000       1.110714
# 2021-01-04    0.36      62.0      46.0    59.0  62.133333       1.002151
# 2021-01-05    0.00      59.0      42.0    59.0  61.966667       1.050282
# ...            ...       ...       ...     ...        ...            ...
# 2022-01-22    0.00      69.0      44.0    60.0  56.833333       0.823671
# 2022-01-23    0.00      60.0      41.0    60.0  56.900000       0.948333
# 2022-01-24    0.00      60.0      39.0    57.0  57.066667       0.951111
# 2022-01-25    0.00      57.0      43.0    57.0  57.200000       1.003509
# 2022-01-26    0.00      57.0      41.0    67.0  57.400000       1.007018
#
#              max_min
# DATE
# 2021-01-01  1.500000
# 2021-01-02  1.117647
# ...

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
    predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(test["target"],predictions)
# Out:
# 20.61083473453592

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    57.0    59.809719
# 2021-01-02    56.0    59.312237
# 2021-01-03    62.0    58.541462
# 2021-01-04    59.0    61.533584
# 2021-01-05    59.0    59.447767
# ...            ...          ...
# 2022-01-22    60.0    67.017372
# 2022-01-23    60.0    59.989268
# 2022-01-24    57.0    59.630169
# 2022-01-25    57.0    58.185216
# 2022-01-26    67.0    57.826117
#
# [390 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_  #shows that precip. has -ve impact on temp., the max. temp. is a bigger i/p
# Out:
# array([-2.20981338,  0.72105054,  0.17954946])

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
predictors = ["precip", "temp_max", "temp_min", "month_day_max", "max_min"]

error, combined = create_predictions(predictors, core_weather, reg)
error
# Out:
# 20.221994983823603

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather["temp_max"].groupby(core_weather.index.month).apply(lambda x: x.expanding(1).mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:12304, in _reindex_for_setitem(value, index)
#   12303 try:
# > 12304     reindexed_value = value.reindex(index)._values
#   12305 except ValueError as err:
#   12306     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4981, in Series.reindex(self, index, axis, method, copy, level, fill_value, limit, tolerance)
#    4964 @doc(
#    4965     NDFrame.reindex,  # type: ignore[has-type]
#    4966     klass=_shared_doc_kwargs["klass"],
#    (...)
#    4979     tolerance=None,
#    4980 ) -> Series:
# -> 4981     return super().reindex(
#    4982         index=index,
#    4983         method=method,
#    4984         copy=copy,
#    4985         level=level,
#    4986         fill_value=fill_value,
# ...

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1960-03-01    0.00      55.0      43.0    58.0        NaN            NaN
# 1960-03-02    0.00      58.0      40.0    62.0        NaN            NaN
# 1960-03-03    0.00      62.0      47.0    62.0        NaN            NaN
# 1960-03-04    0.00      62.0      52.0    58.0        NaN            NaN
# 1960-03-05    0.13      58.0      54.0    59.0        NaN            NaN
# ...            ...       ...       ...     ...        ...            ...
# 2022-01-22    0.00      69.0      44.0    60.0  56.833333       0.823671
# 2022-01-23    0.00      60.0      41.0    60.0  56.900000       0.948333
# 2022-01-24    0.00      60.0      39.0    57.0  57.066667       0.951111
# 2022-01-25    0.00      57.0      43.0    57.0  57.200000       1.003509
# 2022-01-26    0.00      57.0      41.0    67.0  57.400000       1.007018
#
#              max_min
# DATE
# 1960-03-01  1.279070
# 1960-03-02  1.450000
# ...

# %%
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.day_of_year).apply(lambda x: x.expanding(1).mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:12304, in _reindex_for_setitem(value, index)
#   12303 try:
# > 12304     reindexed_value = value.reindex(index)._values
#   12305 except ValueError as err:
#   12306     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4981, in Series.reindex(self, index, axis, method, copy, level, fill_value, limit, tolerance)
#    4964 @doc(
#    4965     NDFrame.reindex,  # type: ignore[has-type]
#    4966     klass=_shared_doc_kwargs["klass"],
#    (...)
#    4979     tolerance=None,
#    4980 ) -> Series:
# -> 4981     return super().reindex(
#    4982         index=index,
#    4983         method=method,
#    4984         copy=copy,
#    4985         level=level,
#    4986         fill_value=fill_value,
# ...

# %%
predictors=["precip","temp_max","temp_min","target","month_max","month_day_max","max_min","day_of_year_avg","monthly_avg"]

# %%
error, combined = create_predictions(predictors + ["monthly_avg", "day_of_year_avg"], core_weather, reg)
error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 error, combined = create_predictions(predictors + ["monthly_avg", "day_of_year_avg"], core_weather, reg)
#       2 error
#
# Cell In[94], line 5, in create_predictions(predictors, core_weather, reg)
#       2 train = core_weather.loc[:"2020-12-31"]
#       3 test = core_weather.loc["2021-01-01":]
# ----> 5 reg.fit(train[predictors], train["target"])
#       6 predictions = reg.predict(test[predictors])
#       8 error = mean_squared_error(test["target"], predictions)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
# ...

# %%
reg.coef_
# Out:
# array([-1.77604315,  0.83471598,  0.12359195, 13.17150274,  0.14239687])

# %%
core_weather.corr()["target"]
# Out:
# precip          -0.205381
# temp_max         0.821605
# temp_min         0.595909
# target           1.000000
# month_max        0.687073
# month_day_max   -0.422057
# max_min          0.045365
# Name: target, dtype: float64

# %%
combined["diff"]=(combined["actual"]-combined["predictions"]).abs()

# %%
combined.sort_values("diff",ascending=False).head(10)
# Out:
#             actual  predictions       diff
# DATE
# 2021-04-01    62.0    76.267999  14.267999
# 2021-05-07    81.0    67.016068  13.983932
# 2021-01-17    83.0    69.782539  13.217461
# 2021-02-21    77.0    64.282623  12.717377
# 2021-10-16    66.0    78.662613  12.662613
# 2021-03-30    82.0    69.813749  12.186251
# 2021-10-04    69.0    81.007949  12.007949
# 2021-03-29    74.0    62.183802  11.816198
# 2021-02-22    84.0    72.202353  11.797647
# 2021-07-07    79.0    67.212938  11.787062
